# %%
import pandas as pd

# %%
df = pd.read_csv(
            "/work/wassmer/napc_xlstm/cctv/cctv_All_passenger_bb_sel_350_100_25_2.csv",
            header=None,
            names=[
                "fname",
                "n_boarding",
                "n_alighting",
                "n_frame",
                "event_boarding",
                "bb_boarding",
                "event_alighting",
                "bb_alighting",
                "n_boarding_N",
                "n_alighting_N",
                "frame_N",
            ],
        )

df.head()

# %%
df.query("n_frame > 1215")
