# %% [markdown]
# ### Data overview

# %%
import sys
sys.path.append('..')
from napc.cctv_dataset import *
dm = DataModule()
dm.setup()
val_dataloader = dm.val_dataloader()
train_dataloader = dm.train_dataloader()

# %%
for x in enumerate(val_dataloader):
    print(x[0])
    break

x[0] # batch index (dataloader)
x[1] # actual batch (implemented in dataset)
x[1][0][0] # cstream sample 0 of 32
x[1][1][0] # label sample 0 of 32
x[1][1][0][0][0] # upper bound boarding sample 0 of 32
x[1][1][0][0][1] # upper bound alighting sample 0 of 32
x[1][1][0][0][2] # lower bound boarding sample 0 of 32
x[1][1][0][0][3] # lower bound alighting sample 0 of 32
x[1][2][0] # length sample 0 of 32
x[1][3][0] # accuracy sample 0 of 32
x[1][4][0] # stream id sample 0 of 32
